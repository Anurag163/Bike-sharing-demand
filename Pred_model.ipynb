# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
from sklearn.linear_model import LinearRegression,ridge_regression
import datetime

#Extra setting
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %%
#Loading train and test
try:
    train=pd.read_csv('/home/anuragverma/Desktop/Kaggle/Bike-Sharing demand/train.csv')
    test=pd.read_csv('/home/anuragverma/Desktop/Kaggle/Bike-Sharing demand/test.csv')
    print('Train shape',train.shape)
    print('Test shape',test.shape)
except FileNotFoundError:
    print('File not found')
# Out:
# Train shape (10886, 12)
# Test shape (6493, 9)

# %%
train.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.head(5)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
train.describe(include='all')
# Out:
#                    datetime        season       holiday    workingday  \
# count                 10886  10886.000000  10886.000000  10886.000000
# unique                10886           NaN           NaN           NaN
# top     2011-01-01 00:00:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN      2.506614      0.028569      0.680875
# std                     NaN      1.116174      0.166599      0.466159
# min                     NaN      1.000000      0.000000      0.000000
# 25%                     NaN      2.000000      0.000000      0.000000
# 50%                     NaN      3.000000      0.000000      1.000000
# 75%                     NaN      4.000000      0.000000      1.000000
# max                     NaN      4.000000      1.000000      1.000000
#
#              weather         temp         atemp      humidity     windspeed  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
train['datetime']=pd.to_datetime(train['datetime'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
# Extract the date from the datetime column
train['date'] = train['datetime'].dt.date

# %%
result2 = train.groupby('date').size().sort_index().reset_index(name='count')
result2.head(5)
# Out:
#          date  count
# 0  2011-01-01     24
# 1  2011-01-02     23
# 2  2011-01-03     22
# 3  2011-01-04     23
# 4  2011-01-05     23

# %%
train.head(5)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count        date
# 0        81        0.0       3          13     16  2011-01-01
# 1        80        0.0       8          32     40  2011-01-01
# 2        80        0.0       5          27     32  2011-01-01
# 3        75        0.0       3          10     13  2011-01-01
# 4        75        0.0       0           1      1  2011-01-01

# %%
display(train[train['date']=='2011-01-01'])
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count, date]
# Index: []

# %%
display(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  date        10886 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(8), object(1)
# memory usage: 1.1+ MB
# None

# %%
display(train[train['date'] == datetime.date(2011, 1, 1)])
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 10 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# ...

# %%
#No Null for train and test
print('train_null_check\n')
print(train.isnull().sum(),'\n')
print('test_null_check\n')
print(test.isnull().sum())
# Out:
# train_null_check
#
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# date          0
# dtype: int64
#
# test_null_check
#
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# dtype: int64

# %%
#No. of zero check
zero_train_check=(train==0).sum()
zero_test_check=(test==0).sum()


# Create a DataFrame to display the results
zeros_train_df = pd.DataFrame({
    'Train_Zeros': zero_train_check,
    'Train_shape': (zero_train_check/train.shape[0])*100,
    'Test_Zeros': zero_test_check,
    'Test_shape': (zero_test_check/test.shape[0])*100

})

print(zeros_train_df[zeros_train_df['Train_Zeros']!=0])
# Out:
#             Train_Zeros  Train_shape  Test_Zeros  Test_shape
# casual              986     9.057505         NaN         NaN
# holiday           10575    97.143120      6304.0   97.089173
# humidity             22     0.202094         0.0    0.000000
# registered           15     0.137792         NaN         NaN
# windspeed          1313    12.061363       867.0   13.352842
# workingday         3474    31.912548      2040.0   31.418451
